# %% [markdown]
# # 01 - Exploration
#
# ## Why we do this first
#
# Students: inspect the dataset before training any model.
# Teacher: guide discussion and ask groups to explain what they think each feature means.
#
# Exploration helps avoid a common pitfall: fitting models without understanding the data.
#
# **Success criterion for this notebook:** each group can explain at least 2 data insights before modeling.

# %%
import os, sys
from pathlib import Path

# Detect Colab
IN_COLAB = "google.colab" in sys.modules

if IN_COLAB:
    if not os.path.exists("/content/citm1b"):
        # !git clone https://github.com/MwiseG/citm1b.git
    # %cd /content/citm1b/worksop1_class
else:
    # Local: find the project root robustly even if cell is rerun.
    cwd = Path.cwd()
    if cwd.name == "notebooks":
        project_root = cwd.parent
    elif (cwd / "src").exists():
        project_root = cwd
    else:
        candidates = [p for p in [cwd] + list(cwd.parents) if (p / "src").exists()]
        project_root = candidates[0] if candidates else cwd

    os.chdir(project_root)
    print("Running locally from:", os.getcwd())

# Ensure src imports work in both environments
if os.getcwd() not in sys.path:
    sys.path.insert(0, os.getcwd())

print("cwd:", os.getcwd())
print("files:", os.listdir(".")[:10])
# Out:
# Running locally from: C:\Users\gimb\Documents\teaching\c1tm1b\lab1\lab1_solutions\handson-ml3\workshop1\worksop1_class
# cwd: C:\Users\gimb\Documents\teaching\c1tm1b\lab1\lab1_solutions\handson-ml3\workshop1\worksop1_class
# files: ['data', 'environment.md', 'notebooks', 'README.md', 'src', 'teacher_guide.md', 'tests']

# %%
import pandas as pd
import matplotlib.pyplot as plt

from src.data_loading import load_housing_data

# Load features + target, then combine for easier exploration.
data, target = load_housing_data()
data = data.copy()
data["MedHouseVal"] = target

# First look: check column names and raw values.
data.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
# info(): data types + non-null counts. describe(): quick summary statistics.
data.info()
data.describe()

# %% [markdown]
# ## TODO 1 (5-10 min, group discussion)
#
# - Which features do you think are most related to house prices?
# - Are there columns you do not understand yet?
#
# Write your guesses in the next markdown cell.
#
# **Tip:** make a guess now, then compare with correlations later.

# %% [markdown]
# ### Group notes
#
# -
# -
# -
#
# (Use short, concrete statements you can reuse in your presentation.)

# %%
# TODO 2: plot histograms for the main numeric attributes.
# Why: this helps you see skewed features, caps, and unusual ranges.
# Hint: use data.hist(bins=50, figsize=(12, 8))

# YOUR CODE HERE
# Example solution:
# data.hist(bins=50, figsize=(12, 8)); plt.tight_layout(); plt.show()

# %%
# TODO 3: compute correlation with the target and interpret the result.
# Correlation shows linear association (not causation).
# If this fails, read the error carefully, fix step by step,
# ask your neighbor, or ask an LLM for a hint.

# YOUR CODE HERE
# Example solution:
# corr_matrix = data.corr(numeric_only=True)
# corr_with_target = corr_matrix["MedHouseVal"].sort_values(ascending=False)
# corr_with_target

# %% [markdown]
# ## PAUSE & DISCUSS
#
# Stop here!!
#
# - Which features seem most strongly related to `MedHouseVal`?
# - Which observation surprised you?
# - What do you still not understand about the dataset?
#
# Teacher note: ask groups to compare guesses from TODO 1 with what they now observe.

# %%
# TODO 4: quick scatter plot for geospatial intuition
# Why: location is often informative in housing data.

# YOUR CODE HERE
# Example:
# ax = data.plot(kind="scatter", x="Longitude", y="Latitude", alpha=0.25,
#                c="MedHouseVal", cmap="viridis", colorbar=True, figsize=(8, 6))
# ax.set_title("Longitude vs Latitude (color = MedHouseVal)")
# plt.show()

# %% [markdown]
# ## Final notes for presentation
#
# Write 2-3 key observations your group learned from this dataset.
#
# -
# -
# -
#
# Try to include one data-quality observation and one model-relevance observation.

# %% [markdown]
# ## Extra task (ML engineer practice): Data quality audit
#
# In real projects, engineers do a quick data quality check before deeper modeling.
#
# ### TODO 5
#
# Write code to create a small quality report with at least:
#
# - missing value count per column
# - duplicate row count
# - a simple range check for `Latitude` (expected around `32` to `42`) and `Longitude` (expected around `-125` to `-114`)
#
# Then write 1-2 sentences: is the data good enough to continue, or would you raise a warning?

# %%
# YOUR CODE HERE (TODO 5)

# Suggested structure:
# missing_counts = ...
# duplicate_count = ...
# lat_out_of_range = ...
# lon_out_of_range = ...
# quality_report = ...
# quality_report
